# %%
import torch

from util_funcs import *
from data_processors import *
import logging
from trainer import Trainer, DeepTwistTrainer
from pytorch_pretrained_bert.modeling import BertForSequenceClassification
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
import re
from glob import glob

f_names = glob('output/deeptwist/*/pytorch_model.bin')

def parse_fname(f_name):
    m = re.match('output/(deeptwist)/(prune|svd|diff_prune)([0-9]*)_([0-9\-_]*)/pytorch_model[.]bin', 
             f_name)
    return m.groups() + (f_name,)
    

models_df = pd.DataFrame([parse_fname(f_name) for f_name in f_names], 
             columns=['framework', 'type', 'param', 'date', 'f_name'])
models_df['date'] = pd.to_datetime(models_df.date, format='%Y-%m-%d_%H_%M')

# %%
processor = processors['sst-2']()
logging.basicConfig(format = '%(asctime)s - %(levelname)s - %(name)s -   %(message)s',
                    datefmt = '%m/%d/%Y %H:%M:%S',
                    level = logging.INFO, 
                    filename=f"log_dir/{get_log_name()}.txt")
logger = logging.getLogger(__name__)

runtime_config = dict(data_dir = "glue_data/SST-2",
                      bert_model = "bert-base-uncased",
                      output_mode = "classification",
                      max_seq_length = 64,
                      local_rank = -1,
                      batch_size = 32,
                      num_train_epochs = 32,
                      do_lower_case=True,
                      do_train=True,
                      train_batch_size=32,
                      gradient_accumulation_steps = 1,
                      n_gpu = 1,
                      learning_rate = 5e-5,
                      logger=logger,
                      warmup_proportion = 0.1)
locals().update(runtime_config)
assert train_batch_size == batch_size

label_list, num_labels, tokenizer, train_examples, \
           num_train_optimization_steps, train_dataloader = get_data(processor, runtime_config)

eval_examples = processor.get_dev_examples(data_dir)
eval_dataloader = get_dataloader(
                eval_examples, label_list,
                tokenizer, eval_data=True,
                **runtime_config)

device = torch.device("cuda" if torch.cuda.is_available() else 'cpu')
loss_fn = CrossEntropyLoss()

base_model = BertForSequenceClassification.from_pretrained(
            bert_model, num_labels=num_labels).cpu().state_dict()

decorator = to_bert(base_model)
diff_prune = decorator(weight_prune)

model = BertForSequenceClassification.from_pretrained(
    bert_model, num_labels=num_labels).to(device)

optimizer = get_optimizer(
    model, num_train_optimization_steps=num_train_optimization_steps, 
    **runtime_config)

tensorboard_log_dir = "tensorboard_data/"
tb_writer = SummaryWriter(log_dir=tensorboard_log_dir)
trainer = DeepTwistTrainer(
    model=model, data=train_dataloader, val_data=eval_dataloader,
    num_labels=num_labels,
    output_dir=output_dir,
    twist_frequency=10,
    loss_fn=loss_fn,
    optimizer=optimizer,
    distort=diff_prune,
    twist_args={'p': 0.1},
    writer=tb_writer,
    device=device,
    **runtime_config,
)

# %%
def eval_model(model):
    trainer.model = model
    return trainer.validate()

def eval_bert_state_dict(f_name, model=model):
    try:
        state_dict = torch.load(f_name)
        model.load_state_dict(state_dict)
        return eval_model(model)
    except RuntimeError:
        return (np.NaN, np.NaN)

# %%
val_loss = []
val_acc = []
for f_name in tqdm(f_names):
    loss, acc = eval_bert_state_dict(f_name)
    val_loss.append(loss)
    val_acc.append(acc)
# Out:
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))

# %%
models_df['val_loss'] = val_loss
models_df['val_acc'] = val_acc
models_df = models_df[['framework', 'type', 'param', 'val_loss', 'val_acc', 'date', 'f_name']]
models_df.sort_values(by='val_acc', ascending=False).reset_index(drop=True).to_csv('report/result_table.csv')

# %%
models_df.sort_values(by='val_acc', ascending=False).reset_index(drop=True) \
    .style.bar(subset=['val_acc'], color='lightgreen', vmin=0, vmax=1)
# Out:
# <style  type="text/css" >
#     #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 92.0%, transparent 92.0%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 91.6%, transparent 91.6%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 91.6%, transparent 91.6%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 91.6%, transparent 91.6%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 91.3%, transparent 91.3%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 90.9%, transparent 90.9%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 89.0%, transparent 89.0%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 88.6%, transparent 88.6%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 84.5%, transparent 84.5%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row9_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 84.5%, transparent 84.5%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row10_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 82.8%, transparent 82.8%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row11_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 82.8%, transparent 82.8%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row12_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 82.3%, transparent 82.3%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row13_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 81.8%, transparent 81.8%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row14_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 81.5%, transparent 81.5%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row15_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 81.0%, transparent 81.0%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row16_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 76.7%, transparent 76.7%);
#         }    #T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row17_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 50.9%, transparent 50.9%);
#         }</style><table id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >framework</th>        <th class="col_heading level0 col1" >type</th>        <th class="col_heading level0 col2" >param</th>        <th class="col_heading level0 col3" >val_loss</th>        <th class="col_heading level0 col4" >val_acc</th>        <th class="col_heading level0 col5" >date</th>        <th class="col_heading level0 col6" >f_name</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col0" class="data row0 col0" >deeptwist</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col1" class="data row0 col1" >diff_prune</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col2" class="data row0 col2" >60</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col3" class="data row0 col3" >0.20893</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col4" class="data row0 col4" >0.919725</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col5" class="data row0 col5" >2019-04-29 03:23:00</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row0_col6" class="data row0 col6" >output/deeptwist/diff_prune60_2019-04-29_03_23/pytorch_model.bin</td>
#             </tr>
#             <tr>
#                         <th id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col0" class="data row1 col0" >deeptwist</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col1" class="data row1 col1" >diff_prune</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col2" class="data row1 col2" >80</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col3" class="data row1 col3" >0.22175</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col4" class="data row1 col4" >0.916284</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col5" class="data row1 col5" >2019-04-29 07:46:00</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row1_col6" class="data row1 col6" >output/deeptwist/diff_prune80_2019-04-29_07_46/pytorch_model.bin</td>
#             </tr>
#             <tr>
#                         <th id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col0" class="data row2 col0" >deeptwist</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col1" class="data row2 col1" >diff_prune</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col2" class="data row2 col2" >90</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col3" class="data row2 col3" >0.216181</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col4" class="data row2 col4" >0.916284</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col5" class="data row2 col5" >2019-04-29 13:48:00</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row2_col6" class="data row2 col6" >output/deeptwist/diff_prune90_2019-04-29_13_48/pytorch_model.bin</td>
#             </tr>
#             <tr>
#                         <th id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row3_col0" class="data row3 col0" >deeptwist</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row3_col1" class="data row3 col1" >diff_prune</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row3_col2" class="data row3 col2" >95</td>
#                         <td id="T_2a50d5ca_6c3d_11e9_ae84_000d3a178ae8row3_col3" class="data row3 col3" >0.220871</td>
